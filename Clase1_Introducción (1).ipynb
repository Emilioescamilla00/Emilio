# %% [markdown]
# # Clase 1 - Introducción a Python

# %%
print('hola')
# Out:
# hola

# %%
import numpy as np

# %%
x = 50
numeros_aleatorios = np.random.rand(x)
numeros_aleatorios
# Out:
# array([0.74020579, 0.95145167, 0.35756921, 0.05915351, 0.47990091,
#        0.16515329, 0.82252458, 0.51889746, 0.11731576, 0.85788658,
#        0.46450582, 0.05575185, 0.22657911, 0.01693318, 0.70538779,
#        0.80563393, 0.81557419, 0.85808131, 0.34671549, 0.77634898,
#        0.22301472, 0.30877525, 0.53227239, 0.9529479 , 0.47855679,
#        0.20298229, 0.20870524, 0.17134271, 0.61318724, 0.42789404,
#        0.17020812, 0.75697626, 0.32619016, 0.24143895, 0.6740049 ,
#        0.00339595, 0.54725216, 0.13892315, 0.44387711, 0.00197648,
#        0.36256941, 0.63280097, 0.52490916, 0.05514037, 0.76992459,
#        0.05123765, 0.93710191, 0.75721287, 0.61755857, 0.87411283])

# %%
x = 50 #es lo mismo solo le cambio el nombre de la variable para guardarla
y = np.random.rand(x)
y
# Out:
# array([0.11234817, 0.15048235, 0.40094467, 0.34774057, 0.02687652,
#        0.76614732, 0.24453276, 0.42096662, 0.43528149, 0.87604883,
#        0.87185195, 0.60754914, 0.6296219 , 0.54845414, 0.68390662,
#        0.62720347, 0.89048213, 0.00157217, 0.19469976, 0.54313004,
#        0.28368993, 0.18119184, 0.66164525, 0.12225499, 0.06543599,
#        0.76556534, 0.48357065, 0.49053572, 0.00776556, 0.1197215 ,
#        0.91383043, 0.70952986, 0.96606161, 0.64779897, 0.45709947,
#        0.74976767, 0.67096803, 0.76590292, 0.38190554, 0.34820099,
#        0.95977482, 0.44607439, 0.76477332, 0.71441651, 0.49942802,
#        0.92517424, 0.70965774, 0.16629748, 0.84311965, 0.21992316])

# %%
# %ls #para saber que esta guardado en la carpeta
# Out:
# 00_00_primer_pasos.ipynb              Clase1_Introducción.ipynb
# 01_01_data_types.ipynb                Clase1.ipynb
# 01_02_read_iloc_unique_groupby.ipynb  datasets/
# 02_00_data_wrangling.ipynb            README.md
# 02_01_null_display.ipynb              requirements.txt
# 02_02_basic_math.ipynb

# %%
# %ls datasets/ #para ver que hay dentro de la carpeta
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Tipos de datos

# %%
import math

# %%
type('hola')
# Out:
# str

# %%
type(4) #al escribir type, nos arroja el tipo de dato que es
# Out:
# int

# %%
print(4)
# Out:
# 4

# %%
type(4.0)
# Out:
# float

# %%
type(4.5)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
type(-3.5)
# Out:
# float

# %%
x = 'nombre 1'
x
# Out:
# 'nombre 1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5] #para listas siempre se usan corchetes
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers) #para conocer el typo de datos
# Out:
# list

# %%
print(numbers) #solo te imprime lo que le dices
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers[0]
# Out:
# 1

# %%
numbers[4]
# Out:
# 5

# %%
sum_numbers = sum(numbers) #si lo hago asi es porque quiero guardar la variable sum_numbers
sum_numbers
# Out:
# 15

# %%
sum(numbers) #se puede hacer directo si no quiero guardar la variable
# Out:
# 15

# %%
lenth = len(numbers) #nos sirve para el obtener la media
lenth
# Out:
# 5

# %%
promedio = sum_numbers/lenth
promedio
# Out:
# 3.0

# %%
type(3/5) #para conocer el typo
# Out:
# float

# %%
3/5 #o (3/5) da lo mismo
# Out:
# 0.6

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, 'nombre', True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(numbers)
# Out:
# list

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None) #si escibes type(none) con minuscula sale error
# Out:
# NoneType

# %%
x = 6
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
# Out:
# 6 es menor que 8

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else: 
    print(x, 'es mayor que', y)
# Out:
# 16 es mayor que 8

# %%
unalista = [True, 6<5, 1==3, None is None]
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## el uso de for loop

# %%
for element in unalista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# # lista

# %%
unaLista = ['first', 'second', 'third', 'forth', 'fifth', 'sixth']
unaLista
# Out:
# ['first', 'second', 'third', 'forth', 'fifth', 'sixth']

# %%
# para que se acomode en orden alfabetico se hace : unaLista.sort() y abajo unaLista par que se imprima

# %%
unaLista[:1]
# Out:
# ['first']

# %%
unaLista[:3]
# Out:
# ['first', 'second', 'third']

# %%
unaLista[:]
# Out:
# ['first', 'second', 'third', 'forth', 'fifth', 'sixth']

# %%
unaLista[1:3]
# Out:
# ['second', 'third']

# %%
unaLista[5]
# Out:
# 'sixth'

# %%
unaLista[-1:]
# Out:
# ['sixth']

# %%
unaLista[-3:-1]
# Out:
# ['forth', 'fifth']

# %%
unaLista[-3:]
# Out:
# ['forth', 'fifth', 'sixth']
