# %% [markdown]
# # Clase 1 Introducción a Python

# %%
print('hola')
# Out:
# hola

# %%
x = 'nombre'
x
# Out:
# 'nombre'

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
sum(numbers)
# Out:
# 15

# %%
lenth = len(numbers)
lenth

# %%
x = 6
y = 8
if x < y;
    print('{} es menor que {}'.format(x,y))
else:
    print(x, 'es mayor que' , y)
