# %% [markdown]
# # Clase 4: Gráficas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(2, 3, 'x') # 'x' es un marker de matplotlib

plt.title('Un titulo', fontsize = 16) #fontsize sirve para el tamaño del titulo

plt.xticks(fontsize = 16, rotation = 45) #sirve para acomodar el tamaño y rotacion del eje X
plt.yticks(fontsize = 16) #lo mismo pero para el eje Y

plt.xlabel('eje X', fontsize = 16) #sirve para poner nombre al eje X
plt.ylabel('eje Y', fontsize = 16) #sirve para poner nombre al eje Y

plt.show() #esto sirve ya que a veces la grafica no aparece, pero ahorita si funiono bin

# %% [markdown]
# ### esta es nuestra propia base de datos

# %%
data = {'Nombres': ['Nombre1', 'Nombre2', 'Nombre3', 'Nombre4'],
        'Edad': [25, 30, 65, 80],
        'Peso': [30, 80, 40, 60],
       }
df = pd.DataFrame(data)
df
# Out:
#    Nombres  Edad  Peso
# 0  Nombre1    25    30
# 1  Nombre2    30    80
# 2  Nombre3    65    40
# 3  Nombre4    80    60

# %%
df.plot(kind='line')

# %%
df['Edad']
# Out:
# 0    25
# 1    30
# 2    65
# 3    80
# Name: Edad, dtype: int64

# %%
df['Edad'].plot(kind='hist') #nos da la frecuencia

# %%
#pip install seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
df = pd.read_csv('datasets/Cartwheeldata.csv')
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %% [markdown]
# # Introducción
#
# ## Descripcion de variables de interes
#
# ### Mis variables de interes son 'Genero', 'Height', 'Wingspan', 'CWDistance'
# * 'Gender' es una variable categorica y explica los generos...
# * 'Height' ...

# %% [markdown]
# ## Pregunta de investigación: 1
# ### ¿Existe alguna correlacion entre 'Wingspan' y 'CWDistance'?

# %%
sns.lmplot (x = 'Wingspan', 
             y = 'CWDistance',
             data = df
            )

plt.show()

# %%
sns.lmplot (x = 'Wingspan', 
             y = 'CWDistance',
             data = df,
            fit_reg = False,
            hue = 'Gender'
            )
plt.title('Scatter plot of Wingspan vs CWDistance', fontsize = 17)
plt.xticks(fontsize = 15, rotation = 45)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# ## Conclusión:
# ### No se encontro ninguna correlacion entre 'Wingsp.......

# %%
sns.swarmplot(x = 'Gender',
              y = 'Wingspan',
              data = df
             )

# %% [markdown]
# ### * Genero F tiene ___ de Wingspan y M tiene ___

# %%
df.shape
# Out:
# (25, 12)

# %%
df.describe()
# Out:
#               ID        Age  GenderGroup  GlassesGroup     Height   Wingspan  \
# count  25.000000  25.000000    25.000000     25.000000  25.000000  25.000000
# mean   13.000000  28.240000     1.520000      0.560000  67.650000  66.260000
# std     7.359801   6.989754     0.509902      0.506623   4.431187   5.492647
# min     1.000000  22.000000     1.000000      0.000000  61.500000  57.500000
# 25%     7.000000  24.000000     1.000000      0.000000  64.000000  62.000000
# 50%    13.000000  26.000000     2.000000      1.000000  68.000000  66.000000
# 75%    19.000000  29.000000     2.000000      1.000000  71.000000  71.000000
# max    25.000000  56.000000     2.000000      1.000000  75.000000  76.000000
#
#        CWDistance  CompleteGroup      Score
# count   25.000000       25.00000  25.000000
# mean    82.480000        0.76000   6.400000
# std     15.058552        0.43589   2.533114
# min     63.000000        0.00000   2.000000
# 25%     70.000000        1.00000   4.000000
# ...

# %%
df['Wingspan'].describe()
# Out:
# count    25.000000
# mean     66.260000
# std       5.492647
# min      57.500000
# 25%      62.000000
# 50%      66.000000
# 75%      71.000000
# max      76.000000
# Name: Wingspan, dtype: float64

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
sns.boxplot(data = df.loc[:, ['Age', 'Height', 'Wingspan', 'CWDistance']],
           )

# %%
sns.boxplot(data = df['Age']
           )

# %%
df[['Age', 'Height', 'Wingspan', 'CWDistance']]
# Out:
#     Age  Height  Wingspan  CWDistance
# 0    56   62.00      61.0          79
# 1    26   62.00      60.0          70
# 2    33   66.00      64.0          85
# 3    39   64.00      63.0          87
# 4    27   73.00      75.0          72
# 5    24   75.00      71.0          81
# 6    28   75.00      76.0         107
# 7    22   65.00      62.0          98
# 8    29   74.00      73.0         106
# 9    33   63.00      60.0          65
# 10   30   69.50      66.0          96
# 11   28   62.75      58.0          79
# 12   25   65.00      64.5          92
# 13   23   61.50      57.5          66
# 14   31   73.00      74.0          72
# 15   26   71.00      72.0         115
# 16   26   61.50      59.5          90
# 17   27   66.00      66.0          74
# 18   23   70.00      69.0          64
# 19   24   68.00      66.0          85
# 20   23   69.00      67.0          66
# 21   29   71.00      70.0         101
# 22   25   70.00      68.0          82
# 23   26   69.00      71.0          63
# ...

# %%
sns.boxplot(data = df.loc[df['Gender'] == 'F', 
                          ['Age', 'Height', 'Wingspan', 'CWDistance']],
           ).set_title('Box plot de Genero F')
# Out:
# Text(0.5, 1.0, 'Box plot de Genero F')

# %%
sns.boxplot(data = df.loc[df['Gender'] == 'M', 
                          ['Age', 'Height', 'Wingspan', 'CWDistance']],
           ).set_title('Box plot de Genero M')
# Out:
# Text(0.5, 1.0, 'Box plot de Genero M')

# %%
fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1) # 1 column, 2 row, 1 position
sns.boxplot(data = df.loc[df['Gender'] == 'F', 'Score']).set_title('Box plot Gender F')

ax2 = fig.add_subplot(1, 2, 2) # 1 column, 2 row, 1 position
sns.boxplot(data = df.loc[df['Gender'] == 'M', ['Score']]).set_title('Box plot Gender M')
# Out:
# Text(0.5, 1.0, 'Box plot Gender M')

# %% [markdown]
# # histogram

# %%
sns.histplot(df.CWDistance, kde = True)

# %%
sns.countplot(x = 'Gender', data = df)

# %%
df = pd.read_csv('datasets/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(df['total_bill'],
             kde = False,
            bins = 20).set_title('Histogram of total bill')
# Out:
# Text(0.5, 1.0, 'Histogram of total bill')

# %%
sns.boxplot(x = df['total_bill']).set_title('Boxplot of total bill')
# Out:
# Text(0.5, 1.0, 'Boxplot of total bill')

# %%
sns.boxplot(x = df['total_bill'],
           whis = (0, 100)).set_title('Boxplot of total bill') #whis sirve para que no sean atipicos
# Out:
# Text(0.5, 1.0, 'Boxplot of total bill')

# %%
sns.boxplot(x = df['total_bill'],
           whis = (0, 100),
           y = df['day']
           ).set_title('Boxplot of total bill') #whis sirve para que no sean atipicos
# Out:
# Text(0.5, 1.0, 'Boxplot of total bill')

# %%
sns.boxplot(x = df['total_bill'],
           whis = (0, 100),
           y = df['sex']
           ).set_title('Boxplot of total bill') #whis sirve para que no sean atipicos
# Out:
# Text(0.5, 1.0, 'Boxplot of total bill')

# %%
fig, ((ax1, ax2, ax3),
      (ax4, ax5, ax6),
      (ax7, ax8, ax9)
     ) = plt.subplots(3, 3, sharex = True, sharey = True)

ax1.plot(2, 3, 'x')
ax5.plot(2, 3, 'x')
ax9.plot(2, 3, 'x')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['tip'].min()
# Out:
# 1.0

# %%
df['tip'].max()
# Out:
# 10.0

# %%
range_tip = (df['tip']>3)&(df['tip']<7)
range_tip
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
total_bills = df[range_tip]
total_bills
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 232       11.61  3.39    Male     No  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
#
# [95 rows x 7 columns]

# %%
total_bills = df[range_tip]
total_bills['tip'].max()
# Out:
# 6.73

# %%
total_bills = df[range_tip]
total_bills['tip'].min()
# Out:
# 3.02

# %%
dias_fav = ['Sun', 'Sat']
x = df['day'].isin(dias_fav)
x
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
dias_fav = ['Sun', 'Sat']
x = df['day'].isin(dias_fav)
new_x = df[x]
new_x
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
pd.set_option('display.max_rows', 500)
new_x
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 0         16.99   1.01  Female     No  Sun  Dinner     2
# 1         10.34   1.66    Male     No  Sun  Dinner     3
# 2         21.01   3.50    Male     No  Sun  Dinner     3
# 3         23.68   3.31    Male     No  Sun  Dinner     2
# 4         24.59   3.61  Female     No  Sun  Dinner     4
# 5         25.29   4.71    Male     No  Sun  Dinner     4
# 6          8.77   2.00    Male     No  Sun  Dinner     2
# 7         26.88   3.12    Male     No  Sun  Dinner     4
# 8         15.04   1.96    Male     No  Sun  Dinner     2
# 9         14.78   3.23    Male     No  Sun  Dinner     2
# 10        10.27   1.71    Male     No  Sun  Dinner     2
# 11        35.26   5.00  Female     No  Sun  Dinner     4
# 12        15.42   1.57    Male     No  Sun  Dinner     2
# 13        18.43   3.00    Male     No  Sun  Dinner     4
# 14        14.83   3.02  Female     No  Sun  Dinner     2
# ...
