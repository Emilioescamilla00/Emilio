# %% [markdown]
# # Tarea clase 3

# %%
import pandas as pd
import numpy as np

# %%
# %ls
# Out:
#  00_00_primer_pasos.ipynb               Clase2pt2.ipynb
#  01_01_data_types.ipynb                'Clase3_pt1 (1).ipynb'
#  01_02_read_iloc_unique_groupby.ipynb   Clase3_pt2.ipynb
#  02_00_data_wrangling.ipynb             datasets/
#  02_01_null_display.ipynb               README.md
#  02_02_basic_math.ipynb                 requirements.txt
# 'Clase1_Introducción (2) (1).ipynb'     TareaClase3.ipynb
#  Clase_2.ipynb

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
df = pd.read_csv('datasets/antropometria-dataset.csv')
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
my_pivot = pd.pivot_table(df,
                          index = ['desc_ent', 'entidad'], #aqui puedes poner lo que quieras, si es uno se pone '__', si son más se pone ['__', '__']
                          values = 'peso',
                          aggfunc = ['mean', 'median'],#aqui puedes poner lo que estes buscando, sum, mean, median, std... en tipo '___' o si quieres varias ['_', '_']
                          columns = 'sexo',
                          margins = True)
my_pivot
# Out:
#                                               mean                        \
# sexo                                             1          2        All
# desc_ent                        entidad
# AGUASCALIENTES                  1        69.985381  63.254292  66.357786
# BAJA CALIFORNIA                 2        71.391818  65.893667  68.467270
# BAJA CALIFORNIA SUR             3        75.561015  68.168959  71.809198
# CAMPECHE                        4        68.622637  62.920493  65.418475
# CHIAPAS                         7        58.365222  57.096111  57.613775
# CHIHUAHUA                       8        68.892642  64.815295  66.656005
# COAHUILA DE ZARAGOZA            5        68.873094  67.467348  68.154142
# COLIMA                          6        70.998878  66.978393  68.743648
# DISTRITO FEDERAL                9        69.460661  61.654128  65.119273
# DURANGO                         10       68.846451  64.400031  66.354922
# ...

# %% [markdown]
# ## problema 2

# %%
import pandas as pd
import numpy as np

# %%
# %ls
# Out:
#  00_00_primer_pasos.ipynb               Clase2pt2.ipynb
#  01_01_data_types.ipynb                'Clase3_pt1 (1).ipynb'
#  01_02_read_iloc_unique_groupby.ipynb   Clase3_pt2.ipynb
#  02_00_data_wrangling.ipynb             datasets/
#  02_01_null_display.ipynb               README.md
#  02_02_basic_math.ipynb                 requirements.txt
# 'Clase1_Introducción (2) (1).ipynb'     TareaClase3.ipynb
#  Clase_2.ipynb

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
df = pd.read_csv('datasets/adult.csv')
df
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
# 32561   52       Self-emp-inc  287927     HS-grad              9
# 32562   52       Self-emp-inc  287927     HS-grad              9
# 32563   52       Self-emp-inc  287927     HS-grad              9
#
#               marital-status          occupation    relationship    race  \
# 0              Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'the label'],
#       dtype='object')

# %%
my_pivot = pd.pivot_table(df,
                          index = ['education', 'sex'], #aqui puedes poner lo que quieras, si es uno se pone '__', si son más se pone ['__', '__']
                          values = 'age', # tambien se puede aqui hacer lo mismo para tener más variables
                          #aggfunc = ['std', 'sum', 'mean', 'median'] #aqui puedes poner lo que estes buscando, sum, mean, median, std... en tipo '___' o si quieres varias ['_', '_']
                          aggfunc = ['mean','median'],
                          columns = 'marital-status',
                          margins = True
                         )
my_pivot
# Out:
#                             mean                                         \
# marital-status          Divorced  Married-AF-spouse  Married-civ-spouse
# education     sex
#  10th          Female  45.343284                NaN           38.363636
#                Male    42.603774                NaN           46.936709
#  11th          Female  41.531646                NaN           38.657143
#                Male    40.764706                NaN           42.987461
#  12th          Female  40.588235                NaN           37.700000
#                Male    41.909091                NaN           42.654545
#  1st-4th       Female  62.200000                NaN           42.666667
#                Male    63.200000                NaN           48.306667
#  5th-6th       Female  53.000000                NaN           41.555556
#                Male    54.400000                NaN           46.376623
#  7th-8th       Female  50.060606                NaN           44.652174
# ...
