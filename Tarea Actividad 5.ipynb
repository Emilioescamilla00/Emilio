# %% [markdown]
# # Tarea Actividad 5

# %%
#pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
df = pd.read_csv('datasets/antropometria-dataset.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
sns.boxplot(x = df['peso'],
           whis = (0, 100)).set_title('Boxplot of peso')
# Out:
# Text(0.5, 1.0, 'Boxplot of peso')

# %%
edad_median = pd.pivot_table(df,
                             index = ['desc_ent'],
                             columns = ['sexo'],
                             values = ['edad'],
                             aggfunc = {'edad':['median']}
                             )
edad_median
# Out:
#                                   edad
#                                 median
# sexo                                 1     2
# desc_ent
# AGUASCALIENTES                    28.5  28.0
# BAJA CALIFORNIA                   25.0  29.5
# BAJA CALIFORNIA SUR               29.0  29.0
# CAMPECHE                          33.0  30.0
# CHIAPAS                           24.0  28.0
# CHIHUAHUA                         32.0  34.0
# COAHUILA DE ZARAGOZA              26.0  33.0
# COLIMA                            30.0  34.0
# DISTRITO FEDERAL                  26.0  26.0
# DURANGO                           30.0  35.0
# GUANAJUATO                        22.0  34.0
# GUERRERO                          27.0  37.0
# HIDALGO                           26.0  35.0
# JALISCO                           30.5  36.0
# MEXICO                            20.0  28.0
# MICHOACAN DE OCAMPO               31.0  32.0
# MORELOS                           29.0  35.0
# NAYARIT                           30.0  35.0
# ...

# %%
edad_median = tabla.boxplot(column=[('edad', 'median', 1)])

# %%
cadera_median = pd.pivot_table(df, index = ['desc_ent'],
                          columns = ['sexo'],
                          values = ['cadera'],
                          aggfunc = {'cadera':['median']}
)
cadera_median
# Out:
#                                   cadera
#                                   median
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                    95.650  100.000
# BAJA CALIFORNIA                   97.600  100.500
# BAJA CALIFORNIA SUR              100.300  101.800
# CAMPECHE                          96.900   99.975
# CHIAPAS                           91.000   94.550
# CHIHUAHUA                         97.400  100.600
# COAHUILA DE ZARAGOZA              96.400  102.400
# COLIMA                            98.050  102.600
# DISTRITO FEDERAL                  96.525   99.900
# DURANGO                           96.700   98.500
# GUANAJUATO                        93.875   98.000
# GUERRERO                          91.425   96.550
# HIDALGO                           93.000   96.100
# JALISCO                           94.575  101.050
# MEXICO                            93.500   96.475
# MICHOACAN DE OCAMPO               94.450   99.150
# ...

# %%
line_plot = cadera_median[('cadera','median', 1)].plot(kind='line')

# %%
plot_ropa = pd.pivot_table(df,
                           index = ['desc_ent'],
                           columns = ['sexo'], 
                           values = ['ropa'], 
                           aggfunc = {'ropa':['sum']}
                          )
plot_ropa
# Out:
#                                 ropa
#                                  sum
# sexo                               1    2
# desc_ent
# AGUASCALIENTES                   493  579
# BAJA CALIFORNIA                  402  466
# BAJA CALIFORNIA SUR              415  440
# CAMPECHE                         350  443
# CHIAPAS                          378  540
# CHIHUAHUA                        415  526
# COAHUILA DE ZARAGOZA             417  439
# COLIMA                           410  543
# DISTRITO FEDERAL                 247  298
# DURANGO                          425  515
# GUANAJUATO                       467  590
# GUERRERO                         431  570
# HIDALGO                          311  518
# JALISCO                          352  479
# MEXICO                           269  370
# MICHOACAN DE OCAMPO              408  543
# MORELOS                          361  554
# NAYARIT                          400  542
# NUEVO LEON                       427  530
# ...

# %%
ropa = plot_ropa.sort_values(('ropa','sum',2),ascending=False) 
top10 = ropa.head(10)
top10
# Out:
#                                 ropa
#                                  sum
# sexo                               1    2
# desc_ent
# SAN LUIS POTOSI                  537  694
# VERACRUZ DE IGNACIO DE LA LLAVE  454  667
# GUANAJUATO                       467  590
# AGUASCALIENTES                   493  579
# GUERRERO                         431  570
# QUERETARO                        496  566
# MORELOS                          361  554
# OAXACA                           372  551
# MICHOACAN DE OCAMPO              408  543
# COLIMA                           410  543

# %%
top10[('ropa','sum', 1)].plot(kind = 'barh', 
                             figsize = (10,5),
                             color = 'b', 
                             alpha = 1)

# %%
sns.histplot(df['cintura'],
             kde = False,
            bins = 25).set_title('Histogram of cintura')
# Out:
# Text(0.5, 1.0, 'Histogram of cintura')
