# %% [markdown]
# # Evidencia

# %%
#pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %ls evidencia_visualización_de_datos.csv
# Out:
# evidencia_visualización_de_datos.csv

# %%
df = pd.read_csv('evidencia_visualización_de_datos.csv')
df.head()
# Out:
#    gender parental level of education test preparation course  math score  \
# 0  female           bachelor's degree                    none          72
# 1  female                some college               completed          69
# 2  female             master's degree                    none          90
# 3    male          associate's degree                    none          47
# 4    male                some college                    none          76
#
#    reading score  writing score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %% [markdown]
# # ¿Existe alguna correlacion entre 'math score' y 'readig score'?

# %%
sns.lmplot (x = 'reading score', 
             y = 'writing score',
             data = df,
            fit_reg = False,
            hue = 'gender'
            )
plt.title('Scatter plot of reading score vs writing score', fontsize = 17)
plt.xticks(fontsize = 15, rotation = 45)
plt.yticks(fontsize = 15)
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'parental level of education', 'test preparation course',
#        'math score', 'reading score', 'writing score'],
#       dtype='object')

# %%
sns.boxplot(data = df.loc[df['gender'] == 'female',1 
                          ['reading score', 'writing score']],
           ).set_title('Box plot de Genero Female')
# Out:
# Text(0.5, 1.0, 'Box plot de Genero Female')

# %%
sns.boxplot(data = df.loc[df['gender'] == 'male', 
                          ['reading score', 'writing score']],
           ).set_title('Box plot de Genero Male')
# Out:
# Text(0.5, 1.0, 'Box plot de Genero Male')

# %%
sns.histplot(df[['reading score', 'writing score']],
             kde = False,
            bins = 20).set_title('Histogram of total bill')
# Out:
# Text(0.5, 1.0, 'Histogram of total bill')

# %%
sns.boxplot(data = df.loc[:, ['reading score', 'writing score']],
           )

# %%
df[['reading score', 'writing score']]
# Out:
#      reading score  writing score
# 0               72             74
# 1               90             88
# 2               95             93
# 3               57             44
# 4               78             75
# ..             ...            ...
# 995             99             95
# 996             55             55
# 997             71             65
# 998             78             77
# 999             86             86
#
# [1000 rows x 2 columns]
